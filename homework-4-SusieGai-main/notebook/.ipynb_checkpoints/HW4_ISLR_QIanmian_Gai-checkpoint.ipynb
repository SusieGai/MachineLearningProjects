# %% [markdown]
# 6.6.3
# According to the linear regression model, it is a LASSO form shrinkage method.
# a.  iv
# When s approach to 0, the subject part (beta_LASSO) approach to 0, y=beta_zero+epsilon. The RSS term is so small that we can ignore it, the bias increase, and variance decrease. Training error approach to the maximum. When s approach to infinity, the opposite happens. The RSS model approach to the linear regression, bias decrease, and variance increase. Training error approach to 0.
# Therefore, the training error decreases as s increases.
# b. ii
# When s is near 0, the model is overfitted and when s is too large, the model is under fitted. Both extreme would lead to a high test error.
# c. iii
# Explained  in part a.
# d. iv
# Explained  in part a.
# e. v
# Irreducible error could not be obtained by the model (or any model).

# %% [markdown]
# ![ISLRhw4qianmiangai-1.jpg](attachment:ISLRhw4qianmiangai-1.jpg)

# %% [markdown]
# ![ISLRhw4qianmiangai-2.jpg](attachment:ISLRhw4qianmiangai-2.jpg)

# %% [markdown]
# ![ISLRhw4qianmiangai-3.jpg](attachment:ISLRhw4qianmiangai-3.jpg)

# %% [markdown]
# 8.4.5
# Majority vote: Class is Red
# Average prob: Class is not green

# %% [markdown]
# 9.7.3

# %% [markdown]
# a.

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns, matplotlib.pyplot as plt, operator as op

# %%
d={'x1':[3,2,4,1,2,4,4],'x2':[4,2,4,4,1,3,1],'y':['red','red','red','red','blue','blue','blue']}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    x1  x2     y
# 0   3   4   red
# 1   2   2   red
# 2   4   4   red
# 3   1   4   red
# 4   2   1  blue
# 5   4   3  blue
# 6   4   1  blue

# %%
sns.relplot(data=df,x='x1',y='x2', hue='y')

# %% [markdown]
# ![ISLRhw4qianmiangai-4.jpg](attachment:ISLRhw4qianmiangai-4.jpg)

# %% [markdown]
# ![ISLRhw4qianmiangai-5.jpg](attachment:ISLRhw4qianmiangai-5.jpg)
